# %%
import sys

import pm4py

import pandas as pd
import numpy as np

import torch
from torch.utils.data import DataLoader

from sklearn.model_selection import train_test_split

from utils.general_utils import set_stdout_to_file, set_seed

from config.feature_config import FeatureConfig

from model.preprocessor import PreprocessorArtifacts
from model.next_event_model import ProcessLSTM, train_ProcessLSTM, validate_ProcessLSTM

# %% [markdown]
# ### --- Preprocess dataset ---

# %%
set_seed(seed=42)

# %%
log = pm4py.read_xes("../../data/InternationalDeclarations.xes")
# Out:
# C:\Users\dcoralage\Downloads\counterfactual_prediction_experiments\counterfactual_env\lib\site-packages\pm4py\utils.py:1027: UserWarning: Install the optional requirement `r4pm` to import/export files faster. `rustxes` remains supported as a fallback.
#   warnings.warn(
# C:\Users\dcoralage\Downloads\counterfactual_prediction_experiments\counterfactual_env\lib\site-packages\pm4py\util\dt_parsing\parser.py:82: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/6449 [00:00<?, ?it/s]

# %%
df = pm4py.convert_to_dataframe(log)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72151 entries, 0 to 72150
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                72151 non-null  object
#  1   org:resource                      72151 non-null  object
#  2   concept:name                      72151 non-null  object
#  3   time:timestamp                    72151 non-null  datetime64[ns, UTC]
#  4   org:role                          72151 non-null  object
#  5   case:Permit travel permit number  72151 non-null  object
#  6   case:DeclarationNumber            72151 non-null  object
#  7   case:Amount                       72151 non-null  float64
#  8   case:RequestedAmount              72151 non-null  float64
#  9   case:Permit TaskNumber            72151 non-null  object
#  10  case:Permit BudgetNumber          72151 non-null  object
#  11  case:OriginalAmount               72151 non-null  float64
#  12  case:Permit ProjectNumber         72151 non-null  object
#  13  case:concept:name                 72151 non-null  object
#  14  case:Permit OrganizationalEntity  72151 non-null  object
#  15  case:travel permit number         72151 non-null  object
#  16  case:Permit RequestedBudget       72151 non-null  float64
#  17  case:id                           72151 non-null  object
#  18  case:Permit ID                    72151 non-null  object
#  19  case:Permit id                    72151 non-null  object
#  20  case:BudgetNumber                 72151 non-null  object
#  21  case:Permit ActivityNumber        72151 non-null  object
#  22  case:AdjustedAmount               72151 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(5), object(17)
# memory usage: 12.7+ MB

# %%
df.isnull().any()
# Out:
# id                                  False
# org:resource                        False
# concept:name                        False
# time:timestamp                      False
# org:role                            False
# case:Permit travel permit number    False
# case:DeclarationNumber              False
# case:Amount                         False
# case:RequestedAmount                False
# case:Permit TaskNumber              False
# case:Permit BudgetNumber            False
# case:OriginalAmount                 False
# case:Permit ProjectNumber           False
# case:concept:name                   False
# case:Permit OrganizationalEntity    False
# case:travel permit number           False
# case:Permit RequestedBudget         False
# case:id                             False
# case:Permit ID                      False
# case:Permit id                      False
# case:BudgetNumber                   False
# case:Permit ActivityNumber          False
# case:AdjustedAmount                 False
# dtype: bool

# %%
df = df.drop(columns=['case:Permit travel permit number', 'case:DeclarationNumber', 'case:Permit TaskNumber', 'case:Permit BudgetNumber',
                      'case:Permit ProjectNumber', 'case:travel permit number', 'case:id', 'case:Permit ID', 'case:Permit id', 'case:BudgetNumber',
                      'case:Permit ActivityNumber', 'id'])

# %%
df['case:concept:name'] = df['case:concept:name'].astype('string')
df['concept:name'] = df['concept:name'].astype('string')
df['org:resource'] = df['org:resource'].astype('string')
df['org:role'] = df['org:role'].astype('string')
df['case:Permit OrganizationalEntity'] = df['case:Permit OrganizationalEntity'].astype('string')

df['case:Amount'] = df['case:Amount'].astype(np.float32)
df['case:RequestedAmount'] = df['case:RequestedAmount'].astype(np.float32)
df['case:OriginalAmount'] = df['case:OriginalAmount'].astype(np.float32)
df['case:Permit RequestedBudget'] = df['case:Permit RequestedBudget'].astype(np.float32)
df['case:AdjustedAmount'] = df['case:AdjustedAmount'].astype(np.float32)

df['time:timestamp'] = pd.to_datetime(df['time:timestamp'], errors='coerce')

# %%
df = df.sort_values(by=['case:concept:name', 'time:timestamp'], ascending=[True, True])

# %%
df['time_delta'] = df.groupby('case:concept:name')['time:timestamp'].diff()
df['time_delta'] = df['time_delta'].dt.total_seconds().astype(np.float32)
df['time_delta'] = df['time_delta'].fillna(0)

# %%
exclude_cols = ["case:concept:name", "time:timestamp"]

sorted_cols = sorted(
    [c for c in df.columns if c not in exclude_cols]
)

df = df[exclude_cols + sorted_cols]

# %%
df.head(20)
# Out:
#        case:concept:name            time:timestamp  case:AdjustedAmount  \
# 27174   declaration 1002 2018-03-01 10:55:17+00:00           361.392242
# 27175   declaration 1002 2018-03-01 10:55:21+00:00           361.392242
# 27176   declaration 1002 2018-03-01 15:01:48+00:00           361.392242
# 27177   declaration 1002 2018-03-19 00:00:00+00:00           361.392242
# 27178   declaration 1002 2018-03-23 00:00:00+00:00           361.392242
# 27179   declaration 1002 2018-03-27 16:15:02+00:00           361.392242
# 27180   declaration 1002 2018-04-03 17:07:56+00:00           361.392242
# 27181   declaration 1002 2018-04-05 09:45:53+00:00           361.392242
# 27182   declaration 1002 2018-04-05 17:25:23+00:00           361.392242
# 27183   declaration 1002 2018-04-09 17:30:58+00:00           361.392242
# 25078  declaration 10024 2018-02-20 13:51:27+00:00           202.138428
# 25079  declaration 10024 2018-02-20 13:51:34+00:00           202.138428
# 25080  declaration 10024 2018-02-20 16:27:33+00:00           202.138428
# 25081  declaration 10024 2018-02-21 12:58:49+00:00           202.138428
# 25082  declaration 10024 2018-03-17 00:00:00+00:00           202.138428
# 25083  declaration 10024 2018-03-22 00:00:00+00:00           202.138428
# 25084  declaration 10024 2018-04-16 21:08:02+00:00           202.138428
# 25085  declaration 10024 2018-04-16 21:14:17+00:00           202.138428
# 25086  declaration 10024 2018-04-18 13:34:47+00:00           202.138428
# 25087  declaration 10024 2018-04-19 09:15:48+00:00           202.138428
#
#        case:Amount  case:OriginalAmount case:Permit OrganizationalEntity  \
# 27174   361.392242           361.392242        organizational unit 65460
# 27175   361.392242           361.392242        organizational unit 65460
# 27176   361.392242           361.392242        organizational unit 65460
# 27177   361.392242           361.392242        organizational unit 65460
# 27178   361.392242           361.392242        organizational unit 65460
# 27179   361.392242           361.392242        organizational unit 65460
# 27180   361.392242           361.392242        organizational unit 65460
# 27181   361.392242           361.392242        organizational unit 65460
# 27182   361.392242           361.392242        organizational unit 65460
# 27183   361.392242           361.392242        organizational unit 65460
# 25078   202.138428           202.138428        organizational unit 65466
# 25079   202.138428           202.138428        organizational unit 65466
# 25080   202.138428           202.138428        organizational unit 65466
# 25081   202.138428           202.138428        organizational unit 65466
# 25082   202.138428           202.138428        organizational unit 65466
# 25083   202.138428           202.138428        organizational unit 65466
# 25084   202.138428           202.138428        organizational unit 65466
# 25085   202.138428           202.138428        organizational unit 65466
# 25086   202.138428           202.138428        organizational unit 65466
# 25087   202.138428           202.138428        organizational unit 65466
#
#        case:Permit RequestedBudget  case:RequestedAmount  \
# 27174                  1273.252075            361.392242
# 27175                  1273.252075            361.392242
# 27176                  1273.252075            361.392242
# 27177                  1273.252075            361.392242
# 27178                  1273.252075            361.392242
# 27179                  1273.252075            361.392242
# 27180                  1273.252075            361.392242
# 27181                  1273.252075            361.392242
# 27182                  1273.252075            361.392242
# 27183                  1273.252075            361.392242
# 25078                  2134.047852            202.138428
# 25079                  2134.047852            202.138428
# 25080                  2134.047852            202.138428
# 25081                  2134.047852            202.138428
# 25082                  2134.047852            202.138428
# 25083                  2134.047852            202.138428
# 25084                  2134.047852            202.138428
# 25085                  2134.047852            202.138428
# 25086                  2134.047852            202.138428
# 25087                  2134.047852            202.138428
#
#                                    concept:name  org:resource        org:role  \
# 27174              Permit SUBMITTED by EMPLOYEE  STAFF MEMBER        EMPLOYEE
# 27175         Permit APPROVED by ADMINISTRATION  STAFF MEMBER  ADMINISTRATION
# 27176       Permit FINAL_APPROVED by SUPERVISOR  STAFF MEMBER      SUPERVISOR
# 27177                                Start trip  STAFF MEMBER        EMPLOYEE
# 27178                                  End trip  STAFF MEMBER        EMPLOYEE
# 27179         Declaration SUBMITTED by EMPLOYEE  STAFF MEMBER        EMPLOYEE
# 27180    Declaration APPROVED by ADMINISTRATION  STAFF MEMBER  ADMINISTRATION
# 27181  Declaration FINAL_APPROVED by SUPERVISOR  STAFF MEMBER      SUPERVISOR
# 27182                           Request Payment        SYSTEM       UNDEFINED
# 27183                           Payment Handled        SYSTEM       UNDEFINED
# 25078              Permit SUBMITTED by EMPLOYEE  STAFF MEMBER        EMPLOYEE
# 25079         Permit APPROVED by ADMINISTRATION  STAFF MEMBER  ADMINISTRATION
# 25080           Permit APPROVED by BUDGET OWNER  STAFF MEMBER    BUDGET OWNER
# 25081       Permit FINAL_APPROVED by SUPERVISOR  STAFF MEMBER      SUPERVISOR
# 25082                                Start trip  STAFF MEMBER        EMPLOYEE
# 25083                                  End trip  STAFF MEMBER        EMPLOYEE
# 25084         Declaration SUBMITTED by EMPLOYEE  STAFF MEMBER        EMPLOYEE
# 25085    Declaration APPROVED by ADMINISTRATION  STAFF MEMBER  ADMINISTRATION
# 25086      Declaration APPROVED by BUDGET OWNER  STAFF MEMBER    BUDGET OWNER
# 25087  Declaration FINAL_APPROVED by SUPERVISOR  STAFF MEMBER      SUPERVISOR
#
#        time_delta
# 27174         0.0
# 27175         4.0
# 27176     14787.0
# 27177   1501092.0
# 27178    345600.0
# 27179    404102.0
# 27180    607974.0
# 27181    146277.0
# 27182     27570.0
# 27183    345935.0
# 25078         0.0
# 25079         7.0
# 25080      9359.0
# 25081     73876.0
# 25082   2026871.0
# 25083    432000.0
# 25084   2236082.0
# 25085       375.0
# 25086    145230.0
# 25087     70861.0

# %%
num_cases = df['case:concept:name'].nunique()
print(f"Total number of unique cases: {num_cases}")
# Out:
# Total number of unique cases: 6449

# %% [markdown]
# ### --- Feature Configurations ---

# %%
# --- Define feature specs ---
feature_specs = {

    "time_delta": {
        "type":           "continuous",
        "level":          "event",
        "vary":           True,
        "quantile_low":   0.20,
        "quantile_high":  0.80, 
    },

    "case:Amount": {
        "type":           "continuous",
        "level":          "case",
        "vary":           True,
        "quantile_low":   0.05,
        "quantile_high":  0.90, 
                 
    },

    "case:RequestedAmount": {
        "type":           "continuous",
        "level":          "case",
        "vary":           True,
        "quantile_low":   0.05,
        "quantile_high":  0.90, 
                 
    },

    "case:OriginalAmount": {
        "type":           "continuous",
        "level":          "case",
        "vary":           True,
        "quantile_low":   0.05,
        "quantile_high":  0.90, 
                 
    },

    "case:Permit RequestedBudget": {
        "type":           "continuous",
        "level":          "case",
        "vary":           True,
        "quantile_low":   0.05,
        "quantile_high":  0.90, 
                 
    },

    "case:AdjustedAmount": {
        "type":           "continuous",
        "level":          "case",
        "vary":           True,
        "quantile_low":   0.05,
        "quantile_high":  0.90, 
                 
    },

    "org:resource": {
        "type":           "categorical",
        "level":          "event",
        "vary":           True,
    },

    "org:role": {
        "type":           "categorical",
        "level":          "event",
        "vary":           True,
    },

    "case:Permit OrganizationalEntity": {
        "type":           "categorical",
        "level":          "case",
        "vary":           True,
    },

    # immutable
    "concept:name": {
        "type":           "categorical", 
        "level":          "event",
        "vary":           False
    },
}

# %%
feature_config = FeatureConfig.from_dataframe(
    df=df,
    feature_specs=feature_specs,
    activity_feature="concept:name",
    is_robust=True,
    default_quantile_low=0.05,
    default_quantile_high=0.95
)

feature_config.save()

# %%
# feature_config = FeatureConfig.load()

# %%
feature_config.summary()
# Out:
#   activity_feature:    concept:name
#   feature_order:       ['case:AdjustedAmount', 'case:Amount', 'case:OriginalAmount', 'case:Permit OrganizationalEntity', 'case:Permit RequestedBudget', 'case:RequestedAmount', 'concept:name', 'org:resource', 'org:role', 'time_delta']
# --------------------------------------------------------------------------------------------------------------------------------------
# Feature                        Type           Level    Vary   Range/Categories                         MAD        Source
# --------------------------------------------------------------------------------------------------------------------------------------
# time_delta                     continuous     event    yes    [19.00, 518400.00]                       112149.0000 quantile_derived
# case:Amount                    continuous     case     yes    [28.52, 1883.08]                         375.8531   quantile_derived
# case:RequestedAmount           continuous     case     yes    [28.52, 1883.08]                         375.8531   quantile_derived
# case:OriginalAmount            continuous     case     yes    [28.52, 1883.08]                         375.8531   quantile_derived
# case:Permit RequestedBudget    continuous     case     yes    [97.91, 2768.29]                         538.9323   quantile_derived
# case:AdjustedAmount            continuous     case     yes    [28.75, 1883.08]                         375.8531   quantile_derived
# org:resource                   categorical    event    yes    ['STAFF MEMBER', 'SYSTEM']               N/A        data_derived
# org:role                       categorical    event    yes    ['ADMINISTRATION', 'BUDGET OWNER', 'DIRECTOR', ...] N/A        data_derived
# case:Permit OrganizationalEntity categorical    case     yes    ['organizational unit 65454', 'organizational unit 65455', 'organizational unit 65456', ...] N/A        data_derived
# concept:name                   categorical    event    no     ['Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by PRE_APPROVER', ...] N/A        data_derived

# %% [markdown]
# ### --- Next event prediction model ---

# %%
# Transform nan cols to NA
cat_cols = df.select_dtypes(include=["string"]).columns
for col in cat_cols:
    df[col] = df[col].fillna("NA").astype('string')

# %%
case_ids = df["case:concept:name"].unique()

train_cases, val_cases = train_test_split(case_ids, test_size=0.2, random_state=42)

train_df = df[df["case:concept:name"].isin(train_cases)].copy()
val_df   = df[df["case:concept:name"].isin(val_cases)].copy()

# %%
preprocessor_artifacts = PreprocessorArtifacts.build(
    df=train_df,
    feature_config=feature_config,      
    scaler_type="robust",
)

preprocessor_artifacts.save()

# %%
# preprocessor_artifacts = PreprocessorArtifacts.load()

# %%
preprocessor_artifacts.summary()
# Out:
# ===================PreprocessorArtifacts====================
#   scaler:              RobustScaler
#   encoders:            ['org:resource', 'org:role', 'case:Permit OrganizationalEntity', 'concept:name']
#   activity_prototypes: 34 activities
# ============================================================

# %%
# Transform nan cols to 0
float_cols = df.select_dtypes(include=["float32", "float64"]).columns
df[float_cols] = df[float_cols].fillna(0)
train_df[float_cols] = train_df[float_cols].fillna(0)
val_df[float_cols] = val_df[float_cols].fillna(0)

# %%
train_dataset = preprocessor_artifacts.transform_dataframe_to_processdataset(
    df=train_df,
    case_id_field="case:concept:name", 
    sort_field="time:timestamp"
)

val_dataset = preprocessor_artifacts.transform_dataframe_to_processdataset(
    df=val_df,
    case_id_field="case:concept:name", 
    sort_field="time:timestamp"
)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
print(preprocessor_artifacts.get_categorical_feature_cardinality())
# Out:
# {'dynamic_categorical_info': {'concept:name': 34, 'org:resource': 2, 'org:role': 8}, 'static_categorical_info': {'case:Permit OrganizationalEntity': 27}}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
log_file, original_stdout = set_stdout_to_file(filepath="logs/bpic20_Int-model_output.txt")
# Out:
# Epoch 020/100 | Train Loss: 0.3023 | LR: 9.05e-04
# Epoch 040/100 | Train Loss: 0.2650 | LR: 6.55e-04
# Epoch 060/100 | Train Loss: 0.2354 | LR: 3.46e-04
# Epoch 080/100 | Train Loss: 0.2155 | LR: 9.64e-05
# Epoch 100/100 | Train Loss: 0.2094 | LR: 1.00e-06
# Time taken for next event model (training): 580.301193 seconds
# Time taken for next event model (validation): 0.600982 seconds
# Val loss: {'loss': 0.4455796872512344, 'accuracy': 0.8722951939867891, 'f1_macro': 0.5645644296467024, 'f1_weighted': 0.8616580609187201}

# %%
embedding_metadata = preprocessor_artifacts.get_embedding_metadata()

model = ProcessLSTM(
    dynamic_categorical_info=embedding_metadata["dynamic_categorical_info"],
    static_categorical_info=embedding_metadata["static_categorical_info"],
    n_dynamic_continuous=embedding_metadata["n_dynamic_continuous"],
    n_static_continuous=embedding_metadata["n_static_continuous"],
    n_classes=embedding_metadata["n_classes"]
)

train_loss_history = train_ProcessLSTM(
    model=model,
    train_loader=train_loader,
    learning_rate=1e-3,
    criterion=criterion,
    num_epochs=100,
    device=device
)

model.save()

# %%
# model = ProcessLSTM.load()

# %%
val_loss = validate_ProcessLSTM(
    model=model,
    val_loader=val_loader,
    criterion=criterion,
    device=device
)

print("Val loss:", val_loss)

# %% [markdown]
# ### --- Cleanup ---

# %%
# --- Save processed df ---
if df["time:timestamp"].dt.tz is not None:
    df["time:timestamp"] = df["time:timestamp"].dt.tz_convert(None)
df.to_excel("../../data/bpic20_Int.xlsx", index=False, engine="openpyxl")

# %%
sys.stdout = original_stdout
log_file.close()
